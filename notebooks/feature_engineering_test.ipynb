# %%
import sys
sys.path.append('../src')
from data_processing import process_data
import pandas as pd

df = pd.read_csv('../data/raw/data.csv')
processed = process_data(df)
print(processed.shape)
processed.head()
# Out:
# c:\Users\Dataencoder\Desktop\credit-risk-model\notebooks\../src\data_processing.py:148: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   customer_df['std_amount'].fillna(0, inplace=True)
# (3742, 27)
#     recency  frequency  monetary  refund_amount  refund_count  avg_amount  \
# 0  1.937605  -0.253459 -0.100614      -0.017562     -0.125824   -0.153364
# 1  1.937605  -0.253459 -0.100614      -0.017562     -0.125824   -0.153364
# 2  2.158882  -0.212186 -0.088647      -0.020360     -0.112155   -0.069870
# 3 -0.201408  -0.150278 -0.098477      -0.023230     -0.057482   -0.091435
# 4 -0.717722  -0.201868 -0.088267      -0.019893     -0.112155   -0.073846
#
#    std_amount  refund_ratio  ProductCategory_airtime  \
# 0   -0.095504     -0.012164                 2.073016
# 1   -0.095504     -0.012164                 2.073016
# 2   -0.083421     -0.017994                -0.039359
# 3   -0.145414     -0.017994                 0.152675
# 4   -0.088882     -0.017994                 0.312703
#
#    ProductCategory_data_bundles  ...  ChannelId_ChannelId_1  \
# 0                     -0.228416  ...               -0.12953
# 1                     -0.228416  ...               -0.12953
# 2                     -0.228416  ...               -0.12953
# 3                     -0.228416  ...               -0.12953
# 4                     -0.228416  ...               -0.12953
#
#    ChannelId_ChannelId_2  ChannelId_ChannelId_3  ChannelId_ChannelId_5  \
# 0               3.137802              -2.804440              -0.147303
# 1               3.137802              -2.804440              -0.147303
# 2               0.480118              -0.342663              -0.147303
# 3               1.124405              -0.939458              -0.147303
# 4               0.184820              -0.069133              -0.147303
#
#    PricingStrategy_0  PricingStrategy_1  PricingStrategy_2  PricingStrategy_4  \
# 0          -0.111024          -0.233921          -2.469219           2.748125
# 1          -0.111024          -0.233921          -2.469219           2.748125
# 2          -0.111024          -0.233921           0.701114          -0.615809
# 3          -0.111024          -0.233921          -0.739947           0.913252
# 4          -0.111024          -0.233921           0.701114          -0.615809
#
#    most_common_hour  risk_proxy
# 0          0.720595           1
# 1          0.720595           1
# 2         -0.874829           1
# 3          0.321739           1
# 4          0.321739           1
#
# [5 rows x 27 columns]
